# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import faiss

# %%
# Étape 1 : Définir les paragraphes
# Nom du fichier texte à lire
size = "100k"
file_path = f"paragraphs_{size}.txt"

# Initialisation de la liste pour stocker les paragraphes
paragraphs = []

# Ouvrir le fichier en mode lecture
with open(file_path, "r", encoding="utf-8") as f:
    # Lire chaque ligne du fichier
    for ligne in f:
        # Ajouter la ligne à la liste des paragraphes
        paragraphs.append(ligne.strip())  # strip() pour enlever les espaces superflus et les sauts de ligne

# %%
# Test
model = SentenceTransformer('all-mpnet-base-v2')
embeddings = model.encode(paragraphs, show_progress_bar=True, normalize_embeddings=True).astype('float32')
np.save(f'embeddings_{size}.npy', embeddings)
# Out:
# Batches:   0%|          | 0/3328 [00:00<?, ?it/s]

# %%
embeddings = np.load(f'embeddings_{size}.npy')

# %%
# k-means params
k = int(embeddings.shape[0]/39)
d = embeddings.shape[1]
res = faiss.StandardGpuResources()  # Créer les ressources GPU

# %%
# Convertir les données en float32 si ce n'est pas déjà le cas
embeddings = embeddings.astype(np.float32)

# Configurer l'index GPU
flat_config = faiss.GpuIndexFlatConfig()
flat_config.device = 0  # GPU 0

index = faiss.GpuIndexFlatL2(res, d, flat_config)

# Clustering
clustering = faiss.Clustering(d, k)
clustering.train(embeddings, index)

# Récupérer les centroïdes
centroids = faiss.vector_to_array(clustering.centroids).reshape(k, d)
np.save(f'centroids_{size}.npy', centroids)

# %%
centroids = np.load(f'centroids_{size}.npy')

# %% [markdown]
# 50k:
# 8.2s

# %% [markdown]
# 100k:
# 11.5s

# %% [markdown]
# 200k:

# %%
# Paramètres
d = embeddings.shape[1]  # Dimension des embeddings
nlist = 100  # Nombre de cellules de partition pour IVF, à ajuster en fonction de la taille des données
M = 32  # Nombre de sous-vecteurs pour PQ, à ajuster en fonction de la dimension des embeddings
n_bits = 8  # Nombre de bits pour la quantification, généralement entre 8 et 16

# Créer un index de base (par exemple, IndexFlatL2 pour la distance euclidienne)
faiss_index_base = faiss.IndexFlatL2(d)

# Créer l'index IVF avec PQ
quantizer = faiss.IndexFlatL2(d)  # Quantiseur pour l'index IVF
index_ivf = faiss.IndexIVFPQ(quantizer, d, nlist, M, n_bits)

# Vérifier si l'index IVF est déjà entraîné
if not index_ivf.is_trained:
    # Entraîner l'index avec un sous-ensemble d'embeddings (par exemple, un échantillon aléatoire)
    index_ivf.train(embeddings)

# %%
# Convertir l'index IVF+PQ en un index GPU, can't use, range_search not inplemented for GPU
#gpu_index = faiss.index_cpu_to_gpu(res, 0, index_ivf)  # 0 pour utiliser le GPU 0

# %%
# Ajouter les embeddings à l'index
index_ivf.add(embeddings)  # Ajouter les embeddings à l'index
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 50k:

# %% [markdown]
# 100k:
# 43.6s

# %% [markdown]
# 200k:

# %%
def find_similar_paragraphs_gpu(index_ivf, embeddings, threshold=0.75, res=res):
    """
    Recherche tous les voisins proches dont la similarité est >= threshold
    (en utilisant la méthode range_search de FAISS), sur le GPU.
    """
    # Assurer que les embeddings sont en float32
    embeddings = embeddings.astype(np.float32)
    limits, distances, indices = index_ivf.range_search(embeddings, threshold)
    return limits, distances, indices

limits, distances, indices = find_similar_paragraphs_gpu(index_ivf, embeddings, threshold=0.75)
# Out:
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 50k, IndexIVFPQ:
# 1.8s

# %% [markdown]
# 100k, IndexIVFPQ:

# %% [markdown]
# 200k, IndexIVFPQ:

# %%
#np.save(f'limits_{size}.npy', limits)
#np.save(f'distances_{size}.npy', distances)
#np.save(f'indices_{size}.npy', indices)

# %%
for i in range(len(embeddings)-1, len(embeddings)):
    print(f"Vecteur {i}:")
    start = limits[i]  # Début des voisins du i-ème vecteur
    end = limits[i+1]  # Fin des voisins du i-ème vecteur
    for j in range(start, end):
        if indices[j] != i:  # Ne pas inclure le vecteur lui-même
            print(f"  Voisin {indices[j]} avec une distance de {distances[j]:.4f}")
    print()
# Out:
# Vecteur 53247:
#   Voisin 12 avec une distance de 0.0000
#   Voisin 25 avec une distance de 0.0000
#   Voisin 38 avec une distance de 0.0000
#   Voisin 51 avec une distance de 0.0000
#   Voisin 64 avec une distance de 0.0000
#   Voisin 77 avec une distance de 0.0000
#   Voisin 90 avec une distance de 0.0000
#   Voisin 103 avec une distance de 0.0000
#   Voisin 116 avec une distance de 0.0000
#   Voisin 129 avec une distance de 0.0000
#   Voisin 142 avec une distance de 0.0000
#   Voisin 155 avec une distance de 0.0000
#   Voisin 168 avec une distance de 0.0000
#   Voisin 181 avec une distance de 0.0000
#   Voisin 194 avec une distance de 0.0000
#   Voisin 207 avec une distance de 0.0000
#   Voisin 220 avec une distance de 0.0000
#   Voisin 233 avec une distance de 0.0000
#   Voisin 246 avec une distance de 0.0000
#   Voisin 259 avec une distance de 0.0000
#   Voisin 272 avec une distance de 0.0000
#   Voisin 285 avec une distance de 0.0000
#   Voisin 298 avec une distance de 0.0000
#   Voisin 311 avec une distance de 0.0000
#   Voisin 324 avec une distance de 0.0000
#   Voisin 337 avec une distance de 0.0000
#   Voisin 350 avec une distance de 0.0000
#   Voisin 363 avec une distance de 0.0000
#   Voisin 376 avec une distance de 0.0000
#   Voisin 389 avec une distance de 0.0000
#   Voisin 402 avec une distance de 0.0000
#   Voisin 415 avec une distance de 0.0000
#   Voisin 428 avec une distance de 0.0000
#   Voisin 441 avec une distance de 0.0000
#   Voisin 454 avec une distance de 0.0000
#   Voisin 467 avec une distance de 0.0000
#   Voisin 480 avec une distance de 0.0000
#   Voisin 493 avec une distance de 0.0000
#   Voisin 506 avec une distance de 0.0000
#   Voisin 519 avec une distance de 0.0000
#   Voisin 532 avec une distance de 0.0000
#   Voisin 545 avec une distance de 0.0000
#   Voisin 558 avec une distance de 0.0000
#   Voisin 571 avec une distance de 0.0000
#   Voisin 584 avec une distance de 0.0000
#   Voisin 597 avec une distance de 0.0000
#   Voisin 610 avec une distance de 0.0000
#   Voisin 623 avec une distance de 0.0000
#   Voisin 636 avec une distance de 0.0000
#   Voisin 649 avec une distance de 0.0000
#   Voisin 662 avec une distance de 0.0000
#   Voisin 675 avec une distance de 0.0000
#   Voisin 688 avec une distance de 0.0000
#   Voisin 701 avec une distance de 0.0000
#   Voisin 714 avec une distance de 0.0000
#   Voisin 727 avec une distance de 0.0000
#   Voisin 740 avec une distance de 0.0000
#   Voisin 753 avec une distance de 0.0000
#   Voisin 766 avec une distance de 0.0000
#   Voisin 779 avec une distance de 0.0000
#   Voisin 792 avec une distance de 0.0000
#   Voisin 805 avec une distance de 0.0000
#   Voisin 818 avec une distance de 0.0000
#   Voisin 831 avec une distance de 0.0000
#   Voisin 844 avec une distance de 0.0000
#   Voisin 857 avec une distance de 0.0000
#   Voisin 870 avec une distance de 0.0000
#   Voisin 883 avec une distance de 0.0000
#   Voisin 896 avec une distance de 0.0000
#   Voisin 909 avec une distance de 0.0000
#   Voisin 922 avec une distance de 0.0000
#   Voisin 935 avec une distance de 0.0000
#   Voisin 948 avec une distance de 0.0000
#   Voisin 961 avec une distance de 0.0000
#   Voisin 974 avec une distance de 0.0000
#   Voisin 987 avec une distance de 0.0000
#   Voisin 1000 avec une distance de 0.0000
#   Voisin 1013 avec une distance de 0.0000
#   Voisin 1026 avec une distance de 0.0000
#   Voisin 1039 avec une distance de 0.0000
#   Voisin 1052 avec une distance de 0.0000
#   Voisin 1065 avec une distance de 0.0000
#   Voisin 1078 avec une distance de 0.0000
#   Voisin 1091 avec une distance de 0.0000
#   Voisin 1104 avec une distance de 0.0000
#   Voisin 1117 avec une distance de 0.0000
#   Voisin 1130 avec une distance de 0.0000
#   Voisin 1143 avec une distance de 0.0000
#   Voisin 1156 avec une distance de 0.0000
#   Voisin 1169 avec une distance de 0.0000
#   Voisin 1182 avec une distance de 0.0000
#   Voisin 1195 avec une distance de 0.0000
#   Voisin 1208 avec une distance de 0.0000
#   Voisin 1221 avec une distance de 0.0000
#   Voisin 1234 avec une distance de 0.0000
#   Voisin 1247 avec une distance de 0.0000
#   Voisin 1260 avec une distance de 0.0000
#   Voisin 1273 avec une distance de 0.0000
#   Voisin 1286 avec une distance de 0.0000
#   Voisin 1299 avec une distance de 0.0000
#   Voisin 1312 avec une distance de 0.0000
#   Voisin 1325 avec une distance de 0.0000
#   Voisin 1338 avec une distance de 0.0000
#   Voisin 1351 avec une distance de 0.0000
#   Voisin 1364 avec une distance de 0.0000
#   Voisin 1377 avec une distance de 0.0000
#   Voisin 1390 avec une distance de 0.0000
#   Voisin 1403 avec une distance de 0.0000
#   Voisin 1416 avec une distance de 0.0000
#   Voisin 1429 avec une distance de 0.0000
#   Voisin 1442 avec une distance de 0.0000
#   Voisin 1455 avec une distance de 0.0000
#   Voisin 1468 avec une distance de 0.0000
#   Voisin 1481 avec une distance de 0.0000
#   Voisin 1494 avec une distance de 0.0000
#   Voisin 1507 avec une distance de 0.0000
#   Voisin 1520 avec une distance de 0.0000
#   Voisin 1533 avec une distance de 0.0000
#   Voisin 1546 avec une distance de 0.0000
#   Voisin 1559 avec une distance de 0.0000
#   Voisin 1572 avec une distance de 0.0000
#   Voisin 1585 avec une distance de 0.0000
#   Voisin 1598 avec une distance de 0.0000
#   Voisin 1611 avec une distance de 0.0000
#   Voisin 1624 avec une distance de 0.0000
#   Voisin 1637 avec une distance de 0.0000
#   Voisin 1650 avec une distance de 0.0000
#   Voisin 1663 avec une distance de 0.0000
#   Voisin 1676 avec une distance de 0.0000
#   Voisin 1689 avec une distance de 0.0000
#   Voisin 1702 avec une distance de 0.0000
#   Voisin 1715 avec une distance de 0.0000
#   Voisin 1728 avec une distance de 0.0000
#   Voisin 1741 avec une distance de 0.0000
#   Voisin 1754 avec une distance de 0.0000
#   Voisin 1767 avec une distance de 0.0000
#   Voisin 1780 avec une distance de 0.0000
#   Voisin 1793 avec une distance de 0.0000
#   Voisin 1806 avec une distance de 0.0000
#   Voisin 1819 avec une distance de 0.0000
#   Voisin 1832 avec une distance de 0.0000
#   Voisin 1845 avec une distance de 0.0000
#   Voisin 1858 avec une distance de 0.0000
#   Voisin 1871 avec une distance de 0.0000
#   Voisin 1884 avec une distance de 0.0000
#   Voisin 1897 avec une distance de 0.0000
#   Voisin 1910 avec une distance de 0.0000
#   Voisin 1923 avec une distance de 0.0000
#   Voisin 1936 avec une distance de 0.0000
#   Voisin 1949 avec une distance de 0.0000
#   Voisin 1962 avec une distance de 0.0000
#   Voisin 1975 avec une distance de 0.0000
#   Voisin 1988 avec une distance de 0.0000
#   Voisin 2001 avec une distance de 0.0000
#   Voisin 2014 avec une distance de 0.0000
#   Voisin 2027 avec une distance de 0.0000
#   Voisin 2040 avec une distance de 0.0000
#   Voisin 2053 avec une distance de 0.0000
#   Voisin 2066 avec une distance de 0.0000
#   Voisin 2079 avec une distance de 0.0000
#   Voisin 2092 avec une distance de 0.0000
#   Voisin 2105 avec une distance de 0.0000
#   Voisin 2118 avec une distance de 0.0000
#   Voisin 2131 avec une distance de 0.0000
#   Voisin 2144 avec une distance de 0.0000
#   Voisin 2157 avec une distance de 0.0000
#   Voisin 2170 avec une distance de 0.0000
#   Voisin 2183 avec une distance de 0.0000
#   Voisin 2196 avec une distance de 0.0000
#   Voisin 2209 avec une distance de 0.0000
#   Voisin 2222 avec une distance de 0.0000
#   Voisin 2235 avec une distance de 0.0000
#   Voisin 2248 avec une distance de 0.0000
#   Voisin 2261 avec une distance de 0.0000
#   Voisin 2274 avec une distance de 0.0000
#   Voisin 2287 avec une distance de 0.0000
#   Voisin 2300 avec une distance de 0.0000
#   Voisin 2313 avec une distance de 0.0000
#   Voisin 2326 avec une distance de 0.0000
#   Voisin 2339 avec une distance de 0.0000
#   Voisin 2352 avec une distance de 0.0000
#   Voisin 2365 avec une distance de 0.0000
#   Voisin 2378 avec une distance de 0.0000
#   Voisin 2391 avec une distance de 0.0000
#   Voisin 2404 avec une distance de 0.0000
#   Voisin 2417 avec une distance de 0.0000
#   Voisin 2430 avec une distance de 0.0000
#   Voisin 2443 avec une distance de 0.0000
#   Voisin 2456 avec une distance de 0.0000
#   Voisin 2469 avec une distance de 0.0000
#   Voisin 2482 avec une distance de 0.0000
#   Voisin 2495 avec une distance de 0.0000
#   Voisin 2508 avec une distance de 0.0000
#   Voisin 2521 avec une distance de 0.0000
#   Voisin 2534 avec une distance de 0.0000
#   Voisin 2547 avec une distance de 0.0000
#   Voisin 2560 avec une distance de 0.0000
#   Voisin 2573 avec une distance de 0.0000
#   Voisin 2586 avec une distance de 0.0000
#   Voisin 2599 avec une distance de 0.0000
#   Voisin 2612 avec une distance de 0.0000
#   Voisin 2625 avec une distance de 0.0000
#   Voisin 2638 avec une distance de 0.0000
#   Voisin 2651 avec une distance de 0.0000
#   Voisin 2664 avec une distance de 0.0000
#   Voisin 2677 avec une distance de 0.0000
#   Voisin 2690 avec une distance de 0.0000
#   Voisin 2703 avec une distance de 0.0000
#   Voisin 2716 avec une distance de 0.0000
#   Voisin 2729 avec une distance de 0.0000
#   Voisin 2742 avec une distance de 0.0000
#   Voisin 2755 avec une distance de 0.0000
#   Voisin 2768 avec une distance de 0.0000
#   Voisin 2781 avec une distance de 0.0000
#   Voisin 2794 avec une distance de 0.0000
#   Voisin 2807 avec une distance de 0.0000
#   Voisin 2820 avec une distance de 0.0000
#   Voisin 2833 avec une distance de 0.0000
#   Voisin 2846 avec une distance de 0.0000
#   Voisin 2859 avec une distance de 0.0000
#   Voisin 2872 avec une distance de 0.0000
#   Voisin 2885 avec une distance de 0.0000
#   Voisin 2898 avec une distance de 0.0000
#   Voisin 2911 avec une distance de 0.0000
#   Voisin 2924 avec une distance de 0.0000
#   Voisin 2937 avec une distance de 0.0000
#   Voisin 2950 avec une distance de 0.0000
#   Voisin 2963 avec une distance de 0.0000
#   Voisin 2976 avec une distance de 0.0000
#   Voisin 2989 avec une distance de 0.0000
#   Voisin 3002 avec une distance de 0.0000
#   Voisin 3015 avec une distance de 0.0000
#   Voisin 3028 avec une distance de 0.0000
#   Voisin 3041 avec une distance de 0.0000
#   Voisin 3054 avec une distance de 0.0000
#   Voisin 3067 avec une distance de 0.0000
#   Voisin 3080 avec une distance de 0.0000
#   Voisin 3093 avec une distance de 0.0000
#   Voisin 3106 avec une distance de 0.0000
#   Voisin 3119 avec une distance de 0.0000
#   Voisin 3132 avec une distance de 0.0000
#   Voisin 3145 avec une distance de 0.0000
#   Voisin 3158 avec une distance de 0.0000
#   Voisin 3171 avec une distance de 0.0000
#   Voisin 3184 avec une distance de 0.0000
#   Voisin 3197 avec une distance de 0.0000
#   Voisin 3210 avec une distance de 0.0000
#   Voisin 3223 avec une distance de 0.0000
#   Voisin 3236 avec une distance de 0.0000
#   Voisin 3249 avec une distance de 0.0000
#   Voisin 3262 avec une distance de 0.0000
#   Voisin 3275 avec une distance de 0.0000
#   Voisin 3288 avec une distance de 0.0000
#   Voisin 3301 avec une distance de 0.0000
#   Voisin 3314 avec une distance de 0.0000
#   Voisin 3327 avec une distance de 0.0000
#   Voisin 3340 avec une distance de 0.0000
#   Voisin 3353 avec une distance de 0.0000
#   Voisin 3366 avec une distance de 0.0000
#   Voisin 3379 avec une distance de 0.0000
#   Voisin 3392 avec une distance de 0.0000
#   Voisin 3405 avec une distance de 0.0000
#   Voisin 3418 avec une distance de 0.0000
#   Voisin 3431 avec une distance de 0.0000
#   Voisin 3444 avec une distance de 0.0000
#   Voisin 3457 avec une distance de 0.0000
#   Voisin 3470 avec une distance de 0.0000
#   Voisin 3483 avec une distance de 0.0000
#   Voisin 3496 avec une distance de 0.0000
#   Voisin 3509 avec une distance de 0.0000
#   Voisin 3522 avec une distance de 0.0000
#   Voisin 3535 avec une distance de 0.0000
#   Voisin 3548 avec une distance de 0.0000
#   Voisin 3561 avec une distance de 0.0000
#   Voisin 3574 avec une distance de 0.0000
#   Voisin 3587 avec une distance de 0.0000
#   Voisin 3600 avec une distance de 0.0000
#   Voisin 3613 avec une distance de 0.0000
#   Voisin 3626 avec une distance de 0.0000
#   Voisin 3639 avec une distance de 0.0000
#   Voisin 3652 avec une distance de 0.0000
#   Voisin 3665 avec une distance de 0.0000
#   Voisin 3678 avec une distance de 0.0000
#   Voisin 3691 avec une distance de 0.0000
#   Voisin 3704 avec une distance de 0.0000
#   Voisin 3717 avec une distance de 0.0000
#   Voisin 3730 avec une distance de 0.0000
#   Voisin 3743 avec une distance de 0.0000
#   Voisin 3756 avec une distance de 0.0000
#   Voisin 3769 avec une distance de 0.0000
#   Voisin 3782 avec une distance de 0.0000
#   Voisin 3795 avec une distance de 0.0000
#   Voisin 3808 avec une distance de 0.0000
#   Voisin 3821 avec une distance de 0.0000
#   Voisin 3834 avec une distance de 0.0000
#   Voisin 3847 avec une distance de 0.0000
#   Voisin 3860 avec une distance de 0.0000
#   Voisin 3873 avec une distance de 0.0000
#   Voisin 3886 avec une distance de 0.0000
#   Voisin 3899 avec une distance de 0.0000
#   Voisin 3912 avec une distance de 0.0000
#   Voisin 3925 avec une distance de 0.0000
#   Voisin 3938 avec une distance de 0.0000
#   Voisin 3951 avec une distance de 0.0000
#   Voisin 3964 avec une distance de 0.0000
#   Voisin 3977 avec une distance de 0.0000
#   Voisin 3990 avec une distance de 0.0000
#   Voisin 4003 avec une distance de 0.0000
#   Voisin 4016 avec une distance de 0.0000
#   Voisin 4029 avec une distance de 0.0000
#   Voisin 4042 avec une distance de 0.0000
#   Voisin 4055 avec une distance de 0.0000
#   Voisin 4068 avec une distance de 0.0000
#   Voisin 4081 avec une distance de 0.0000
#   Voisin 4094 avec une distance de 0.0000
#   Voisin 4107 avec une distance de 0.0000
#   Voisin 4120 avec une distance de 0.0000
#   Voisin 4133 avec une distance de 0.0000
#   Voisin 4146 avec une distance de 0.0000
#   Voisin 4159 avec une distance de 0.0000
#   Voisin 4172 avec une distance de 0.0000
#   Voisin 4185 avec une distance de 0.0000
#   Voisin 4198 avec une distance de 0.0000
#   Voisin 4211 avec une distance de 0.0000
#   Voisin 4224 avec une distance de 0.0000
#   Voisin 4237 avec une distance de 0.0000
#   Voisin 4250 avec une distance de 0.0000
#   Voisin 4263 avec une distance de 0.0000
#   Voisin 4276 avec une distance de 0.0000
#   Voisin 4289 avec une distance de 0.0000
#   Voisin 4302 avec une distance de 0.0000
#   Voisin 4315 avec une distance de 0.0000
#   Voisin 4328 avec une distance de 0.0000
#   Voisin 4341 avec une distance de 0.0000
#   Voisin 4354 avec une distance de 0.0000
#   Voisin 4367 avec une distance de 0.0000
#   Voisin 4380 avec une distance de 0.0000
#   Voisin 4393 avec une distance de 0.0000
#   Voisin 4406 avec une distance de 0.0000
#   Voisin 4419 avec une distance de 0.0000
#   Voisin 4432 avec une distance de 0.0000
#   Voisin 4445 avec une distance de 0.0000
#   Voisin 4458 avec une distance de 0.0000
#   Voisin 4471 avec une distance de 0.0000
#   Voisin 4484 avec une distance de 0.0000
#   Voisin 4497 avec une distance de 0.0000
#   Voisin 4510 avec une distance de 0.0000
#   Voisin 4523 avec une distance de 0.0000
#   Voisin 4536 avec une distance de 0.0000
#   Voisin 4549 avec une distance de 0.0000
#   Voisin 4562 avec une distance de 0.0000
#   Voisin 4575 avec une distance de 0.0000
#   Voisin 4588 avec une distance de 0.0000
#   Voisin 4601 avec une distance de 0.0000
#   Voisin 4614 avec une distance de 0.0000
#   Voisin 4627 avec une distance de 0.0000
#   Voisin 4640 avec une distance de 0.0000
#   Voisin 4653 avec une distance de 0.0000
#   Voisin 4666 avec une distance de 0.0000
#   Voisin 4679 avec une distance de 0.0000
#   Voisin 4692 avec une distance de 0.0000
#   Voisin 4705 avec une distance de 0.0000
#   Voisin 4718 avec une distance de 0.0000
#   Voisin 4731 avec une distance de 0.0000
#   Voisin 4744 avec une distance de 0.0000
#   Voisin 4757 avec une distance de 0.0000
#   Voisin 4770 avec une distance de 0.0000
#   Voisin 4783 avec une distance de 0.0000
#   Voisin 4796 avec une distance de 0.0000
#   Voisin 4809 avec une distance de 0.0000
#   Voisin 4822 avec une distance de 0.0000
#   Voisin 4835 avec une distance de 0.0000
#   Voisin 4848 avec une distance de 0.0000
#   Voisin 4861 avec une distance de 0.0000
#   Voisin 4874 avec une distance de 0.0000
#   Voisin 4887 avec une distance de 0.0000
#   Voisin 4900 avec une distance de 0.0000
#   Voisin 4913 avec une distance de 0.0000
#   Voisin 4926 avec une distance de 0.0000
#   Voisin 4939 avec une distance de 0.0000
#   Voisin 4952 avec une distance de 0.0000
#   Voisin 4965 avec une distance de 0.0000
#   Voisin 4978 avec une distance de 0.0000
#   Voisin 4991 avec une distance de 0.0000
#   Voisin 5004 avec une distance de 0.0000
#   Voisin 5017 avec une distance de 0.0000
#   Voisin 5030 avec une distance de 0.0000
#   Voisin 5043 avec une distance de 0.0000
#   Voisin 5056 avec une distance de 0.0000
#   Voisin 5069 avec une distance de 0.0000
#   Voisin 5082 avec une distance de 0.0000
#   Voisin 5095 avec une distance de 0.0000
#   Voisin 5108 avec une distance de 0.0000
#   Voisin 5121 avec une distance de 0.0000
#   Voisin 5134 avec une distance de 0.0000
#   Voisin 5147 avec une distance de 0.0000
#   Voisin 5160 avec une distance de 0.0000
#   Voisin 5173 avec une distance de 0.0000
#   Voisin 5186 avec une distance de 0.0000
#   Voisin 5199 avec une distance de 0.0000
#   Voisin 5212 avec une distance de 0.0000
#   Voisin 5225 avec une distance de 0.0000
#   Voisin 5238 avec une distance de 0.0000
#   Voisin 5251 avec une distance de 0.0000
#   Voisin 5264 avec une distance de 0.0000
#   Voisin 5277 avec une distance de 0.0000
#   Voisin 5290 avec une distance de 0.0000
#   Voisin 5303 avec une distance de 0.0000
#   Voisin 5316 avec une distance de 0.0000
#   Voisin 5329 avec une distance de 0.0000
#   Voisin 5342 avec une distance de 0.0000
#   Voisin 5355 avec une distance de 0.0000
#   Voisin 5368 avec une distance de 0.0000
#   Voisin 5381 avec une distance de 0.0000
#   Voisin 5394 avec une distance de 0.0000
#   Voisin 5407 avec une distance de 0.0000
#   Voisin 5420 avec une distance de 0.0000
#   Voisin 5433 avec une distance de 0.0000
#   Voisin 5446 avec une distance de 0.0000
#   Voisin 5459 avec une distance de 0.0000
#   Voisin 5472 avec une distance de 0.0000
#   Voisin 5485 avec une distance de 0.0000
#   Voisin 5498 avec une distance de 0.0000
#   Voisin 5511 avec une distance de 0.0000
#   Voisin 5524 avec une distance de 0.0000
#   Voisin 5537 avec une distance de 0.0000
#   Voisin 5550 avec une distance de 0.0000
#   Voisin 5563 avec une distance de 0.0000
#   Voisin 5576 avec une distance de 0.0000
#   Voisin 5589 avec une distance de 0.0000
#   Voisin 5602 avec une distance de 0.0000
#   Voisin 5615 avec une distance de 0.0000
#   Voisin 5628 avec une distance de 0.0000
#   Voisin 5641 avec une distance de 0.0000
#   Voisin 5654 avec une distance de 0.0000
#   Voisin 5667 avec une distance de 0.0000
#   Voisin 5680 avec une distance de 0.0000
#   Voisin 5693 avec une distance de 0.0000
#   Voisin 5706 avec une distance de 0.0000
#   Voisin 5719 avec une distance de 0.0000
#   Voisin 5732 avec une distance de 0.0000
#   Voisin 5745 avec une distance de 0.0000
#   Voisin 5758 avec une distance de 0.0000
#   Voisin 5771 avec une distance de 0.0000
#   Voisin 5784 avec une distance de 0.0000
#   Voisin 5797 avec une distance de 0.0000
#   Voisin 5810 avec une distance de 0.0000
#   Voisin 5823 avec une distance de 0.0000
#   Voisin 5836 avec une distance de 0.0000
#   Voisin 5849 avec une distance de 0.0000
#   Voisin 5862 avec une distance de 0.0000
#   Voisin 5875 avec une distance de 0.0000
#   Voisin 5888 avec une distance de 0.0000
#   Voisin 5901 avec une distance de 0.0000
#   Voisin 5914 avec une distance de 0.0000
#   Voisin 5927 avec une distance de 0.0000
#   Voisin 5940 avec une distance de 0.0000
#   Voisin 5953 avec une distance de 0.0000
#   Voisin 5966 avec une distance de 0.0000
#   Voisin 5979 avec une distance de 0.0000
#   Voisin 5992 avec une distance de 0.0000
#   Voisin 6005 avec une distance de 0.0000
#   Voisin 6018 avec une distance de 0.0000
#   Voisin 6031 avec une distance de 0.0000
#   Voisin 6044 avec une distance de 0.0000
#   Voisin 6057 avec une distance de 0.0000
#   Voisin 6070 avec une distance de 0.0000
#   Voisin 6083 avec une distance de 0.0000
#   Voisin 6096 avec une distance de 0.0000
#   Voisin 6109 avec une distance de 0.0000
#   Voisin 6122 avec une distance de 0.0000
#   Voisin 6135 avec une distance de 0.0000
#   Voisin 6148 avec une distance de 0.0000
#   Voisin 6161 avec une distance de 0.0000
#   Voisin 6174 avec une distance de 0.0000
#   Voisin 6187 avec une distance de 0.0000
#   Voisin 6200 avec une distance de 0.0000
#   Voisin 6213 avec une distance de 0.0000
#   Voisin 6226 avec une distance de 0.0000
#   Voisin 6239 avec une distance de 0.0000
#   Voisin 6252 avec une distance de 0.0000
#   Voisin 6265 avec une distance de 0.0000
#   Voisin 6278 avec une distance de 0.0000
#   Voisin 6291 avec une distance de 0.0000
#   Voisin 6304 avec une distance de 0.0000
#   Voisin 6317 avec une distance de 0.0000
#   Voisin 6330 avec une distance de 0.0000
#   Voisin 6343 avec une distance de 0.0000
#   Voisin 6356 avec une distance de 0.0000
#   Voisin 6369 avec une distance de 0.0000
#   Voisin 6382 avec une distance de 0.0000
#   Voisin 6395 avec une distance de 0.0000
#   Voisin 6408 avec une distance de 0.0000
#   Voisin 6421 avec une distance de 0.0000
#   Voisin 6434 avec une distance de 0.0000
#   Voisin 6447 avec une distance de 0.0000
#   Voisin 6460 avec une distance de 0.0000
#   Voisin 6473 avec une distance de 0.0000
#   Voisin 6486 avec une distance de 0.0000
#   Voisin 6499 avec une distance de 0.0000
#   Voisin 6512 avec une distance de 0.0000
#   Voisin 6525 avec une distance de 0.0000
#   Voisin 6538 avec une distance de 0.0000
#   Voisin 6551 avec une distance de 0.0000
#   Voisin 6564 avec une distance de 0.0000
#   Voisin 6577 avec une distance de 0.0000
#   Voisin 6590 avec une distance de 0.0000
#   Voisin 6603 avec une distance de 0.0000
#   Voisin 6616 avec une distance de 0.0000
#   Voisin 6629 avec une distance de 0.0000
#   Voisin 6642 avec une distance de 0.0000
#   Voisin 6655 avec une distance de 0.0000
#   Voisin 6668 avec une distance de 0.0000
#   Voisin 6681 avec une distance de 0.0000
#   Voisin 6694 avec une distance de 0.0000
#   Voisin 6707 avec une distance de 0.0000
#   Voisin 6720 avec une distance de 0.0000
#   Voisin 6733 avec une distance de 0.0000
#   Voisin 6746 avec une distance de 0.0000
#   Voisin 6759 avec une distance de 0.0000
#   Voisin 6772 avec une distance de 0.0000
#   Voisin 6785 avec une distance de 0.0000
#   Voisin 6798 avec une distance de 0.0000
#   Voisin 6811 avec une distance de 0.0000
#   Voisin 6824 avec une distance de 0.0000
#   Voisin 6837 avec une distance de 0.0000
#   Voisin 6850 avec une distance de 0.0000
#   Voisin 6863 avec une distance de 0.0000
#   Voisin 6876 avec une distance de 0.0000
#   Voisin 6889 avec une distance de 0.0000
#   Voisin 6902 avec une distance de 0.0000
#   Voisin 6915 avec une distance de 0.0000
#   Voisin 6928 avec une distance de 0.0000
#   Voisin 6941 avec une distance de 0.0000
#   Voisin 6954 avec une distance de 0.0000
#   Voisin 6967 avec une distance de 0.0000
#   Voisin 6980 avec une distance de 0.0000
#   Voisin 6993 avec une distance de 0.0000
#   Voisin 7006 avec une distance de 0.0000
#   Voisin 7019 avec une distance de 0.0000
#   Voisin 7032 avec une distance de 0.0000
#   Voisin 7045 avec une distance de 0.0000
#   Voisin 7058 avec une distance de 0.0000
#   Voisin 7071 avec une distance de 0.0000
#   Voisin 7084 avec une distance de 0.0000
#   Voisin 7097 avec une distance de 0.0000
#   Voisin 7110 avec une distance de 0.0000
#   Voisin 7123 avec une distance de 0.0000
#   Voisin 7136 avec une distance de 0.0000
#   Voisin 7149 avec une distance de 0.0000
#   Voisin 7162 avec une distance de 0.0000
#   Voisin 7175 avec une distance de 0.0000
#   Voisin 7188 avec une distance de 0.0000
#   Voisin 7201 avec une distance de 0.0000
#   Voisin 7214 avec une distance de 0.0000
#   Voisin 7227 avec une distance de 0.0000
#   Voisin 7240 avec une distance de 0.0000
#   Voisin 7253 avec une distance de 0.0000
#   Voisin 7266 avec une distance de 0.0000
#   Voisin 7279 avec une distance de 0.0000
#   Voisin 7292 avec une distance de 0.0000
#   Voisin 7305 avec une distance de 0.0000
#   Voisin 7318 avec une distance de 0.0000
#   Voisin 7331 avec une distance de 0.0000
#   Voisin 7344 avec une distance de 0.0000
#   Voisin 7357 avec une distance de 0.0000
#   Voisin 7370 avec une distance de 0.0000
#   Voisin 7383 avec une distance de 0.0000
#   Voisin 7396 avec une distance de 0.0000
#   Voisin 7409 avec une distance de 0.0000
#   Voisin 7422 avec une distance de 0.0000
#   Voisin 7435 avec une distance de 0.0000
#   Voisin 7448 avec une distance de 0.0000
#   Voisin 7461 avec une distance de 0.0000
#   Voisin 7474 avec une distance de 0.0000
#   Voisin 7487 avec une distance de 0.0000
#   Voisin 7500 avec une distance de 0.0000
#   Voisin 7513 avec une distance de 0.0000
#   Voisin 7526 avec une distance de 0.0000
#   Voisin 7539 avec une distance de 0.0000
#   Voisin 7552 avec une distance de 0.0000
#   Voisin 7565 avec une distance de 0.0000
#   Voisin 7578 avec une distance de 0.0000
#   Voisin 7591 avec une distance de 0.0000
#   Voisin 7604 avec une distance de 0.0000
#   Voisin 7617 avec une distance de 0.0000
#   Voisin 7630 avec une distance de 0.0000
#   Voisin 7643 avec une distance de 0.0000
#   Voisin 7656 avec une distance de 0.0000
#   Voisin 7669 avec une distance de 0.0000
#   Voisin 7682 avec une distance de 0.0000
#   Voisin 7695 avec une distance de 0.0000
#   Voisin 7708 avec une distance de 0.0000
#   Voisin 7721 avec une distance de 0.0000
#   Voisin 7734 avec une distance de 0.0000
#   Voisin 7747 avec une distance de 0.0000
#   Voisin 7760 avec une distance de 0.0000
#   Voisin 7773 avec une distance de 0.0000
#   Voisin 7786 avec une distance de 0.0000
#   Voisin 7799 avec une distance de 0.0000
#   Voisin 7812 avec une distance de 0.0000
#   Voisin 7825 avec une distance de 0.0000
#   Voisin 7838 avec une distance de 0.0000
#   Voisin 7851 avec une distance de 0.0000
#   Voisin 7864 avec une distance de 0.0000
#   Voisin 7877 avec une distance de 0.0000
#   Voisin 7890 avec une distance de 0.0000
#   Voisin 7903 avec une distance de 0.0000
#   Voisin 7916 avec une distance de 0.0000
#   Voisin 7929 avec une distance de 0.0000
#   Voisin 7942 avec une distance de 0.0000
#   Voisin 7955 avec une distance de 0.0000
#   Voisin 7968 avec une distance de 0.0000
#   Voisin 7981 avec une distance de 0.0000
#   Voisin 7994 avec une distance de 0.0000
#   Voisin 8007 avec une distance de 0.0000
#   Voisin 8020 avec une distance de 0.0000
#   Voisin 8033 avec une distance de 0.0000
#   Voisin 8046 avec une distance de 0.0000
#   Voisin 8059 avec une distance de 0.0000
#   Voisin 8072 avec une distance de 0.0000
#   Voisin 8085 avec une distance de 0.0000
#   Voisin 8098 avec une distance de 0.0000
#   Voisin 8111 avec une distance de 0.0000
#   Voisin 8124 avec une distance de 0.0000
#   Voisin 8137 avec une distance de 0.0000
#   Voisin 8150 avec une distance de 0.0000
#   Voisin 8163 avec une distance de 0.0000
#   Voisin 8176 avec une distance de 0.0000
#   Voisin 8189 avec une distance de 0.0000
#   Voisin 8202 avec une distance de 0.0000
#   Voisin 8215 avec une distance de 0.0000
#   Voisin 8228 avec une distance de 0.0000
#   Voisin 8241 avec une distance de 0.0000
#   Voisin 8254 avec une distance de 0.0000
#   Voisin 8267 avec une distance de 0.0000
#   Voisin 8280 avec une distance de 0.0000
#   Voisin 8293 avec une distance de 0.0000
#   Voisin 8306 avec une distance de 0.0000
#   Voisin 8319 avec une distance de 0.0000
#   Voisin 8332 avec une distance de 0.0000
#   Voisin 8345 avec une distance de 0.0000
#   Voisin 8358 avec une distance de 0.0000
#   Voisin 8371 avec une distance de 0.0000
#   Voisin 8384 avec une distance de 0.0000
#   Voisin 8397 avec une distance de 0.0000
#   Voisin 8410 avec une distance de 0.0000
#   Voisin 8423 avec une distance de 0.0000
#   Voisin 8436 avec une distance de 0.0000
#   Voisin 8449 avec une distance de 0.0000
#   Voisin 8462 avec une distance de 0.0000
#   Voisin 8475 avec une distance de 0.0000
#   Voisin 8488 avec une distance de 0.0000
#   Voisin 8501 avec une distance de 0.0000
#   Voisin 8514 avec une distance de 0.0000
#   Voisin 8527 avec une distance de 0.0000
#   Voisin 8540 avec une distance de 0.0000
#   Voisin 8553 avec une distance de 0.0000
#   Voisin 8566 avec une distance de 0.0000
#   Voisin 8579 avec une distance de 0.0000
#   Voisin 8592 avec une distance de 0.0000
#   Voisin 8605 avec une distance de 0.0000
#   Voisin 8618 avec une distance de 0.0000
#   Voisin 8631 avec une distance de 0.0000
#   Voisin 8644 avec une distance de 0.0000
#   Voisin 8657 avec une distance de 0.0000
#   Voisin 8670 avec une distance de 0.0000
#   Voisin 8683 avec une distance de 0.0000
#   Voisin 8696 avec une distance de 0.0000
#   Voisin 8709 avec une distance de 0.0000
#   Voisin 8722 avec une distance de 0.0000
#   Voisin 8735 avec une distance de 0.0000
#   Voisin 8748 avec une distance de 0.0000
#   Voisin 8761 avec une distance de 0.0000
#   Voisin 8774 avec une distance de 0.0000
#   Voisin 8787 avec une distance de 0.0000
#   Voisin 8800 avec une distance de 0.0000
#   Voisin 8813 avec une distance de 0.0000
#   Voisin 8826 avec une distance de 0.0000
#   Voisin 8839 avec une distance de 0.0000
#   Voisin 8852 avec une distance de 0.0000
#   Voisin 8865 avec une distance de 0.0000
#   Voisin 8878 avec une distance de 0.0000
#   Voisin 8891 avec une distance de 0.0000
#   Voisin 8904 avec une distance de 0.0000
#   Voisin 8917 avec une distance de 0.0000
#   Voisin 8930 avec une distance de 0.0000
#   Voisin 8943 avec une distance de 0.0000
#   Voisin 8956 avec une distance de 0.0000
#   Voisin 8969 avec une distance de 0.0000
#   Voisin 8982 avec une distance de 0.0000
#   Voisin 8995 avec une distance de 0.0000
#   Voisin 9008 avec une distance de 0.0000
#   Voisin 9021 avec une distance de 0.0000
#   Voisin 9034 avec une distance de 0.0000
#   Voisin 9047 avec une distance de 0.0000
#   Voisin 9060 avec une distance de 0.0000
#   Voisin 9073 avec une distance de 0.0000
#   Voisin 9086 avec une distance de 0.0000
#   Voisin 9099 avec une distance de 0.0000
#   Voisin 9112 avec une distance de 0.0000
#   Voisin 9125 avec une distance de 0.0000
#   Voisin 9138 avec une distance de 0.0000
#   Voisin 9151 avec une distance de 0.0000
#   Voisin 9164 avec une distance de 0.0000
#   Voisin 9177 avec une distance de 0.0000
#   Voisin 9190 avec une distance de 0.0000
#   Voisin 9203 avec une distance de 0.0000
#   Voisin 9216 avec une distance de 0.0000
#   Voisin 9229 avec une distance de 0.0000
#   Voisin 9242 avec une distance de 0.0000
#   Voisin 9255 avec une distance de 0.0000
#   Voisin 9268 avec une distance de 0.0000
#   Voisin 9281 avec une distance de 0.0000
#   Voisin 9294 avec une distance de 0.0000
#   Voisin 9307 avec une distance de 0.0000
#   Voisin 9320 avec une distance de 0.0000
#   Voisin 9333 avec une distance de 0.0000
#   Voisin 9346 avec une distance de 0.0000
#   Voisin 9359 avec une distance de 0.0000
#   Voisin 9372 avec une distance de 0.0000
#   Voisin 9385 avec une distance de 0.0000
#   Voisin 9398 avec une distance de 0.0000
#   Voisin 9411 avec une distance de 0.0000
#   Voisin 9424 avec une distance de 0.0000
#   Voisin 9437 avec une distance de 0.0000
#   Voisin 9450 avec une distance de 0.0000
#   Voisin 9463 avec une distance de 0.0000
#   Voisin 9476 avec une distance de 0.0000
#   Voisin 9489 avec une distance de 0.0000
#   Voisin 9502 avec une distance de 0.0000
#   Voisin 9515 avec une distance de 0.0000
#   Voisin 9528 avec une distance de 0.0000
#   Voisin 9541 avec une distance de 0.0000
#   Voisin 9554 avec une distance de 0.0000
#   Voisin 9567 avec une distance de 0.0000
#   Voisin 9580 avec une distance de 0.0000
#   Voisin 9593 avec une distance de 0.0000
#   Voisin 9606 avec une distance de 0.0000
#   Voisin 9619 avec une distance de 0.0000
#   Voisin 9632 avec une distance de 0.0000
#   Voisin 9645 avec une distance de 0.0000
#   Voisin 9658 avec une distance de 0.0000
#   Voisin 9671 avec une distance de 0.0000
#   Voisin 9684 avec une distance de 0.0000
#   Voisin 9697 avec une distance de 0.0000
#   Voisin 9710 avec une distance de 0.0000
#   Voisin 9723 avec une distance de 0.0000
#   Voisin 9736 avec une distance de 0.0000
#   Voisin 9749 avec une distance de 0.0000
#   Voisin 9762 avec une distance de 0.0000
#   Voisin 9775 avec une distance de 0.0000
#   Voisin 9788 avec une distance de 0.0000
#   Voisin 9801 avec une distance de 0.0000
#   Voisin 9814 avec une distance de 0.0000
#   Voisin 9827 avec une distance de 0.0000
#   Voisin 9840 avec une distance de 0.0000
#   Voisin 9853 avec une distance de 0.0000
#   Voisin 9866 avec une distance de 0.0000
#   Voisin 9879 avec une distance de 0.0000
#   Voisin 9892 avec une distance de 0.0000
#   Voisin 9905 avec une distance de 0.0000
#   Voisin 9918 avec une distance de 0.0000
#   Voisin 9931 avec une distance de 0.0000
#   Voisin 9944 avec une distance de 0.0000
#   Voisin 9957 avec une distance de 0.0000
#   Voisin 9970 avec une distance de 0.0000
#   Voisin 9983 avec une distance de 0.0000
#   Voisin 9996 avec une distance de 0.0000
#   Voisin 10009 avec une distance de 0.0000
#   Voisin 10022 avec une distance de 0.0000
#   Voisin 10035 avec une distance de 0.0000
#   Voisin 10048 avec une distance de 0.0000
#   Voisin 10061 avec une distance de 0.0000
#   Voisin 10074 avec une distance de 0.0000
#   Voisin 10087 avec une distance de 0.0000
#   Voisin 10100 avec une distance de 0.0000
#   Voisin 10113 avec une distance de 0.0000
#   Voisin 10126 avec une distance de 0.0000
#   Voisin 10139 avec une distance de 0.0000
#   Voisin 10152 avec une distance de 0.0000
#   Voisin 10165 avec une distance de 0.0000
#   Voisin 10178 avec une distance de 0.0000
#   Voisin 10191 avec une distance de 0.0000
#   Voisin 10204 avec une distance de 0.0000
#   Voisin 10217 avec une distance de 0.0000
#   Voisin 10230 avec une distance de 0.0000
#   Voisin 10243 avec une distance de 0.0000
#   Voisin 10256 avec une distance de 0.0000
#   Voisin 10269 avec une distance de 0.0000
#   Voisin 10282 avec une distance de 0.0000
#   Voisin 10295 avec une distance de 0.0000
#   Voisin 10308 avec une distance de 0.0000
#   Voisin 10321 avec une distance de 0.0000
#   Voisin 10334 avec une distance de 0.0000
#   Voisin 10347 avec une distance de 0.0000
#   Voisin 10360 avec une distance de 0.0000
#   Voisin 10373 avec une distance de 0.0000
#   Voisin 10386 avec une distance de 0.0000
#   Voisin 10399 avec une distance de 0.0000
#   Voisin 10412 avec une distance de 0.0000
#   Voisin 10425 avec une distance de 0.0000
#   Voisin 10438 avec une distance de 0.0000
#   Voisin 10451 avec une distance de 0.0000
#   Voisin 10464 avec une distance de 0.0000
#   Voisin 10477 avec une distance de 0.0000
#   Voisin 10490 avec une distance de 0.0000
#   Voisin 10503 avec une distance de 0.0000
#   Voisin 10516 avec une distance de 0.0000
#   Voisin 10529 avec une distance de 0.0000
#   Voisin 10542 avec une distance de 0.0000
#   Voisin 10555 avec une distance de 0.0000
#   Voisin 10568 avec une distance de 0.0000
#   Voisin 10581 avec une distance de 0.0000
#   Voisin 10594 avec une distance de 0.0000
#   Voisin 10607 avec une distance de 0.0000
#   Voisin 10620 avec une distance de 0.0000
#   Voisin 10633 avec une distance de 0.0000
#   Voisin 10646 avec une distance de 0.0000
#   Voisin 10659 avec une distance de 0.0000
#   Voisin 10672 avec une distance de 0.0000
#   Voisin 10685 avec une distance de 0.0000
#   Voisin 10698 avec une distance de 0.0000
#   Voisin 10711 avec une distance de 0.0000
#   Voisin 10724 avec une distance de 0.0000
#   Voisin 10737 avec une distance de 0.0000
#   Voisin 10750 avec une distance de 0.0000
#   Voisin 10763 avec une distance de 0.0000
#   Voisin 10776 avec une distance de 0.0000
#   Voisin 10789 avec une distance de 0.0000
#   Voisin 10802 avec une distance de 0.0000
#   Voisin 10815 avec une distance de 0.0000
#   Voisin 10828 avec une distance de 0.0000
#   Voisin 10841 avec une distance de 0.0000
#   Voisin 10854 avec une distance de 0.0000
#   Voisin 10867 avec une distance de 0.0000
#   Voisin 10880 avec une distance de 0.0000
#   Voisin 10893 avec une distance de 0.0000
#   Voisin 10906 avec une distance de 0.0000
#   Voisin 10919 avec une distance de 0.0000
#   Voisin 10932 avec une distance de 0.0000
#   Voisin 10945 avec une distance de 0.0000
#   Voisin 10958 avec une distance de 0.0000
#   Voisin 10971 avec une distance de 0.0000
#   Voisin 10984 avec une distance de 0.0000
#   Voisin 10997 avec une distance de 0.0000
#   Voisin 11010 avec une distance de 0.0000
#   Voisin 11023 avec une distance de 0.0000
#   Voisin 11036 avec une distance de 0.0000
#   Voisin 11049 avec une distance de 0.0000
#   Voisin 11062 avec une distance de 0.0000
#   Voisin 11075 avec une distance de 0.0000
#   Voisin 11088 avec une distance de 0.0000
#   Voisin 11101 avec une distance de 0.0000
#   Voisin 11114 avec une distance de 0.0000
#   Voisin 11127 avec une distance de 0.0000
#   Voisin 11140 avec une distance de 0.0000
#   Voisin 11153 avec une distance de 0.0000
#   Voisin 11166 avec une distance de 0.0000
#   Voisin 11179 avec une distance de 0.0000
#   Voisin 11192 avec une distance de 0.0000
#   Voisin 11205 avec une distance de 0.0000
#   Voisin 11218 avec une distance de 0.0000
#   Voisin 11231 avec une distance de 0.0000
#   Voisin 11244 avec une distance de 0.0000
#   Voisin 11257 avec une distance de 0.0000
#   Voisin 11270 avec une distance de 0.0000
#   Voisin 11283 avec une distance de 0.0000
#   Voisin 11296 avec une distance de 0.0000
#   Voisin 11309 avec une distance de 0.0000
#   Voisin 11322 avec une distance de 0.0000
#   Voisin 11335 avec une distance de 0.0000
#   Voisin 11348 avec une distance de 0.0000
#   Voisin 11361 avec une distance de 0.0000
#   Voisin 11374 avec une distance de 0.0000
#   Voisin 11387 avec une distance de 0.0000
#   Voisin 11400 avec une distance de 0.0000
#   Voisin 11413 avec une distance de 0.0000
#   Voisin 11426 avec une distance de 0.0000
#   Voisin 11439 avec une distance de 0.0000
#   Voisin 11452 avec une distance de 0.0000
#   Voisin 11465 avec une distance de 0.0000
#   Voisin 11478 avec une distance de 0.0000
#   Voisin 11491 avec une distance de 0.0000
#   Voisin 11504 avec une distance de 0.0000
#   Voisin 11517 avec une distance de 0.0000
#   Voisin 11530 avec une distance de 0.0000
#   Voisin 11543 avec une distance de 0.0000
#   Voisin 11556 avec une distance de 0.0000
#   Voisin 11569 avec une distance de 0.0000
#   Voisin 11582 avec une distance de 0.0000
#   Voisin 11595 avec une distance de 0.0000
#   Voisin 11608 avec une distance de 0.0000
#   Voisin 11621 avec une distance de 0.0000
#   Voisin 11634 avec une distance de 0.0000
#   Voisin 11647 avec une distance de 0.0000
#   Voisin 11660 avec une distance de 0.0000
#   Voisin 11673 avec une distance de 0.0000
#   Voisin 11686 avec une distance de 0.0000
#   Voisin 11699 avec une distance de 0.0000
#   Voisin 11712 avec une distance de 0.0000
#   Voisin 11725 avec une distance de 0.0000
#   Voisin 11738 avec une distance de 0.0000
#   Voisin 11751 avec une distance de 0.0000
#   Voisin 11764 avec une distance de 0.0000
#   Voisin 11777 avec une distance de 0.0000
#   Voisin 11790 avec une distance de 0.0000
#   Voisin 11803 avec une distance de 0.0000
#   Voisin 11816 avec une distance de 0.0000
#   Voisin 11829 avec une distance de 0.0000
#   Voisin 11842 avec une distance de 0.0000
#   Voisin 11855 avec une distance de 0.0000
#   Voisin 11868 avec une distance de 0.0000
#   Voisin 11881 avec une distance de 0.0000
#   Voisin 11894 avec une distance de 0.0000
#   Voisin 11907 avec une distance de 0.0000
#   Voisin 11920 avec une distance de 0.0000
#   Voisin 11933 avec une distance de 0.0000
#   Voisin 11946 avec une distance de 0.0000
#   Voisin 11959 avec une distance de 0.0000
#   Voisin 11972 avec une distance de 0.0000
#   Voisin 11985 avec une distance de 0.0000
#   Voisin 11998 avec une distance de 0.0000
#   Voisin 12011 avec une distance de 0.0000
#   Voisin 12024 avec une distance de 0.0000
#   Voisin 12037 avec une distance de 0.0000
#   Voisin 12050 avec une distance de 0.0000
#   Voisin 12063 avec une distance de 0.0000
#   Voisin 12076 avec une distance de 0.0000
#   Voisin 12089 avec une distance de 0.0000
#   Voisin 12102 avec une distance de 0.0000
#   Voisin 12115 avec une distance de 0.0000
#   Voisin 12128 avec une distance de 0.0000
#   Voisin 12141 avec une distance de 0.0000
#   Voisin 12154 avec une distance de 0.0000
#   Voisin 12167 avec une distance de 0.0000
#   Voisin 12180 avec une distance de 0.0000
#   Voisin 12193 avec une distance de 0.0000
#   Voisin 12206 avec une distance de 0.0000
#   Voisin 12219 avec une distance de 0.0000
#   Voisin 12232 avec une distance de 0.0000
#   Voisin 12245 avec une distance de 0.0000
#   Voisin 12258 avec une distance de 0.0000
#   Voisin 12271 avec une distance de 0.0000
#   Voisin 12284 avec une distance de 0.0000
#   Voisin 12297 avec une distance de 0.0000
#   Voisin 12310 avec une distance de 0.0000
#   Voisin 12323 avec une distance de 0.0000
#   Voisin 12336 avec une distance de 0.0000
#   Voisin 12349 avec une distance de 0.0000
#   Voisin 12362 avec une distance de 0.0000
#   Voisin 12375 avec une distance de 0.0000
#   Voisin 12388 avec une distance de 0.0000
#   Voisin 12401 avec une distance de 0.0000
#   Voisin 12414 avec une distance de 0.0000
#   Voisin 12427 avec une distance de 0.0000
#   Voisin 12440 avec une distance de 0.0000
#   Voisin 12453 avec une distance de 0.0000
#   Voisin 12466 avec une distance de 0.0000
#   Voisin 12479 avec une distance de 0.0000
#   Voisin 12492 avec une distance de 0.0000
#   Voisin 12505 avec une distance de 0.0000
#   Voisin 12518 avec une distance de 0.0000
#   Voisin 12531 avec une distance de 0.0000
#   Voisin 12544 avec une distance de 0.0000
#   Voisin 12557 avec une distance de 0.0000
#   Voisin 12570 avec une distance de 0.0000
#   Voisin 12583 avec une distance de 0.0000
#   Voisin 12596 avec une distance de 0.0000
#   Voisin 12609 avec une distance de 0.0000
#   Voisin 12622 avec une distance de 0.0000
#   Voisin 12635 avec une distance de 0.0000
#   Voisin 12648 avec une distance de 0.0000
#   Voisin 12661 avec une distance de 0.0000
#   Voisin 12674 avec une distance de 0.0000
#   Voisin 12687 avec une distance de 0.0000
#   Voisin 12700 avec une distance de 0.0000
#   Voisin 12713 avec une distance de 0.0000
#   Voisin 12726 avec une distance de 0.0000
#   Voisin 12739 avec une distance de 0.0000
#   Voisin 12752 avec une distance de 0.0000
#   Voisin 12765 avec une distance de 0.0000
#   Voisin 12778 avec une distance de 0.0000
#   Voisin 12791 avec une distance de 0.0000
#   Voisin 12804 avec une distance de 0.0000
#   Voisin 12817 avec une distance de 0.0000
#   Voisin 12830 avec une distance de 0.0000
#   Voisin 12843 avec une distance de 0.0000
#   Voisin 12856 avec une distance de 0.0000
#   Voisin 12869 avec une distance de 0.0000
#   Voisin 12882 avec une distance de 0.0000
#   Voisin 12895 avec une distance de 0.0000
#   Voisin 12908 avec une distance de 0.0000
#   Voisin 12921 avec une distance de 0.0000
#   Voisin 12934 avec une distance de 0.0000
#   Voisin 12947 avec une distance de 0.0000
#   Voisin 12960 avec une distance de 0.0000
#   Voisin 12973 avec une distance de 0.0000
#   Voisin 12986 avec une distance de 0.0000
#   Voisin 12999 avec une distance de 0.0000
#   Voisin 13012 avec une distance de 0.0000
#   Voisin 13025 avec une distance de 0.0000
#   Voisin 13038 avec une distance de 0.0000
#   Voisin 13051 avec une distance de 0.0000
#   Voisin 13064 avec une distance de 0.0000
#   Voisin 13077 avec une distance de 0.0000
#   Voisin 13090 avec une distance de 0.0000
#   Voisin 13103 avec une distance de 0.0000
#   Voisin 13116 avec une distance de 0.0000
#   Voisin 13129 avec une distance de 0.0000
#   Voisin 13142 avec une distance de 0.0000
#   Voisin 13155 avec une distance de 0.0000
#   Voisin 13168 avec une distance de 0.0000
#   Voisin 13181 avec une distance de 0.0000
#   Voisin 13194 avec une distance de 0.0000
#   Voisin 13207 avec une distance de 0.0000
#   Voisin 13220 avec une distance de 0.0000
#   Voisin 13233 avec une distance de 0.0000
#   Voisin 13246 avec une distance de 0.0000
#   Voisin 13259 avec une distance de 0.0000
#   Voisin 13272 avec une distance de 0.0000
#   Voisin 13285 avec une distance de 0.0000
#   Voisin 13298 avec une distance de 0.0000
#   Voisin 13311 avec une distance de 0.0000
#   Voisin 13324 avec une distance de 0.0000
#   Voisin 13337 avec une distance de 0.0000
#   Voisin 13350 avec une distance de 0.0000
#   Voisin 13363 avec une distance de 0.0000
#   Voisin 13376 avec une distance de 0.0000
#   Voisin 13389 avec une distance de 0.0000
#   Voisin 13402 avec une distance de 0.0000
#   Voisin 13415 avec une distance de 0.0000
#   Voisin 13428 avec une distance de 0.0000
#   Voisin 13441 avec une distance de 0.0000
#   Voisin 13454 avec une distance de 0.0000
#   Voisin 13467 avec une distance de 0.0000
#   Voisin 13480 avec une distance de 0.0000
#   Voisin 13493 avec une distance de 0.0000
#   Voisin 13506 avec une distance de 0.0000
#   Voisin 13519 avec une distance de 0.0000
#   Voisin 13532 avec une distance de 0.0000
#   Voisin 13545 avec une distance de 0.0000
#   Voisin 13558 avec une distance de 0.0000
#   Voisin 13571 avec une distance de 0.0000
#   Voisin 13584 avec une distance de 0.0000
#   Voisin 13597 avec une distance de 0.0000
#   Voisin 13610 avec une distance de 0.0000
#   Voisin 13623 avec une distance de 0.0000
#   Voisin 13636 avec une distance de 0.0000
#   Voisin 13649 avec une distance de 0.0000
#   Voisin 13662 avec une distance de 0.0000
#   Voisin 13675 avec une distance de 0.0000
#   Voisin 13688 avec une distance de 0.0000
#   Voisin 13701 avec une distance de 0.0000
#   Voisin 13714 avec une distance de 0.0000
#   Voisin 13727 avec une distance de 0.0000
#   Voisin 13740 avec une distance de 0.0000
#   Voisin 13753 avec une distance de 0.0000
#   Voisin 13766 avec une distance de 0.0000
#   Voisin 13779 avec une distance de 0.0000
#   Voisin 13792 avec une distance de 0.0000
#   Voisin 13805 avec une distance de 0.0000
#   Voisin 13818 avec une distance de 0.0000
#   Voisin 13831 avec une distance de 0.0000
#   Voisin 13844 avec une distance de 0.0000
#   Voisin 13857 avec une distance de 0.0000
#   Voisin 13870 avec une distance de 0.0000
#   Voisin 13883 avec une distance de 0.0000
#   Voisin 13896 avec une distance de 0.0000
#   Voisin 13909 avec une distance de 0.0000
#   Voisin 13922 avec une distance de 0.0000
#   Voisin 13935 avec une distance de 0.0000
#   Voisin 13948 avec une distance de 0.0000
#   Voisin 13961 avec une distance de 0.0000
#   Voisin 13974 avec une distance de 0.0000
#   Voisin 13987 avec une distance de 0.0000
#   Voisin 14000 avec une distance de 0.0000
#   Voisin 14013 avec une distance de 0.0000
#   Voisin 14026 avec une distance de 0.0000
#   Voisin 14039 avec une distance de 0.0000
#   Voisin 14052 avec une distance de 0.0000
#   Voisin 14065 avec une distance de 0.0000
#   Voisin 14078 avec une distance de 0.0000
#   Voisin 14091 avec une distance de 0.0000
#   Voisin 14104 avec une distance de 0.0000
#   Voisin 14117 avec une distance de 0.0000
#   Voisin 14130 avec une distance de 0.0000
#   Voisin 14143 avec une distance de 0.0000
#   Voisin 14156 avec une distance de 0.0000
#   Voisin 14169 avec une distance de 0.0000
#   Voisin 14182 avec une distance de 0.0000
#   Voisin 14195 avec une distance de 0.0000
#   Voisin 14208 avec une distance de 0.0000
#   Voisin 14221 avec une distance de 0.0000
#   Voisin 14234 avec une distance de 0.0000
#   Voisin 14247 avec une distance de 0.0000
#   Voisin 14260 avec une distance de 0.0000
#   Voisin 14273 avec une distance de 0.0000
#   Voisin 14286 avec une distance de 0.0000
#   Voisin 14299 avec une distance de 0.0000
#   Voisin 14312 avec une distance de 0.0000
#   Voisin 14325 avec une distance de 0.0000
#   Voisin 14338 avec une distance de 0.0000
#   Voisin 14351 avec une distance de 0.0000
#   Voisin 14364 avec une distance de 0.0000
#   Voisin 14377 avec une distance de 0.0000
#   Voisin 14390 avec une distance de 0.0000
#   Voisin 14403 avec une distance de 0.0000
#   Voisin 14416 avec une distance de 0.0000
#   Voisin 14429 avec une distance de 0.0000
#   Voisin 14442 avec une distance de 0.0000
#   Voisin 14455 avec une distance de 0.0000
#   Voisin 14468 avec une distance de 0.0000
#   Voisin 14481 avec une distance de 0.0000
#   Voisin 14494 avec une distance de 0.0000
#   Voisin 14507 avec une distance de 0.0000
#   Voisin 14520 avec une distance de 0.0000
#   Voisin 14533 avec une distance de 0.0000
#   Voisin 14546 avec une distance de 0.0000
#   Voisin 14559 avec une distance de 0.0000
#   Voisin 14572 avec une distance de 0.0000
#   Voisin 14585 avec une distance de 0.0000
#   Voisin 14598 avec une distance de 0.0000
#   Voisin 14611 avec une distance de 0.0000
#   Voisin 14624 avec une distance de 0.0000
#   Voisin 14637 avec une distance de 0.0000
#   Voisin 14650 avec une distance de 0.0000
#   Voisin 14663 avec une distance de 0.0000
#   Voisin 14676 avec une distance de 0.0000
#   Voisin 14689 avec une distance de 0.0000
#   Voisin 14702 avec une distance de 0.0000
#   Voisin 14715 avec une distance de 0.0000
#   Voisin 14728 avec une distance de 0.0000
#   Voisin 14741 avec une distance de 0.0000
#   Voisin 14754 avec une distance de 0.0000
# ...
#   Voisin 48411 avec une distance de 0.0000
#   Voisin 48424 avec une distance de 0.0000
#   Voisin 48437 avec une distance de 0.0000
#   Voisin 48450 avec une distance de 0.0000
#   Voisin 48463 avec une distance de 0.0000
#   Voisin 48476 avec une distance de 0.0000
#   Voisin 48489 avec une distance de 0.0000
#   Voisin 48502 avec une distance de 0.0000
#   Voisin 48515 avec une distance de 0.0000
#   Voisin 48528 avec une distance de 0.0000
#   Voisin 48541 avec une distance de 0.0000
#   Voisin 48554 avec une distance de 0.0000
#   Voisin 48567 avec une distance de 0.0000
#   Voisin 48580 avec une distance de 0.0000
#   Voisin 48593 avec une distance de 0.0000
#   Voisin 48606 avec une distance de 0.0000
#   Voisin 48619 avec une distance de 0.0000
#   Voisin 48632 avec une distance de 0.0000
#   Voisin 48645 avec une distance de 0.0000
#   Voisin 48658 avec une distance de 0.0000
#   Voisin 48671 avec une distance de 0.0000
#   Voisin 48684 avec une distance de 0.0000
#   Voisin 48697 avec une distance de 0.0000
#   Voisin 48710 avec une distance de 0.0000
#   Voisin 48723 avec une distance de 0.0000
#   Voisin 48736 avec une distance de 0.0000
#   Voisin 48749 avec une distance de 0.0000
#   Voisin 48762 avec une distance de 0.0000
#   Voisin 48775 avec une distance de 0.0000
#   Voisin 48788 avec une distance de 0.0000
#   Voisin 48801 avec une distance de 0.0000
#   Voisin 48814 avec une distance de 0.0000
#   Voisin 48827 avec une distance de 0.0000
#   Voisin 48840 avec une distance de 0.0000
#   Voisin 48853 avec une distance de 0.0000
#   Voisin 48866 avec une distance de 0.0000
#   Voisin 48879 avec une distance de 0.0000
#   Voisin 48892 avec une distance de 0.0000
#   Voisin 48905 avec une distance de 0.0000
#   Voisin 48918 avec une distance de 0.0000
#   Voisin 48931 avec une distance de 0.0000
#   Voisin 48944 avec une distance de 0.0000
#   Voisin 48957 avec une distance de 0.0000
#   Voisin 48970 avec une distance de 0.0000
#   Voisin 48983 avec une distance de 0.0000
#   Voisin 48996 avec une distance de 0.0000
#   Voisin 49009 avec une distance de 0.0000
#   Voisin 49022 avec une distance de 0.0000
#   Voisin 49035 avec une distance de 0.0000
#   Voisin 49048 avec une distance de 0.0000
#   Voisin 49061 avec une distance de 0.0000
#   Voisin 49074 avec une distance de 0.0000
#   Voisin 49087 avec une distance de 0.0000
#   Voisin 49100 avec une distance de 0.0000
#   Voisin 49113 avec une distance de 0.0000
#   Voisin 49126 avec une distance de 0.0000
#   Voisin 49139 avec une distance de 0.0000
#   Voisin 49152 avec une distance de 0.0000
#   Voisin 49165 avec une distance de 0.0000
#   Voisin 49178 avec une distance de 0.0000
#   Voisin 49191 avec une distance de 0.0000
#   Voisin 49204 avec une distance de 0.0000
#   Voisin 49217 avec une distance de 0.0000
#   Voisin 49230 avec une distance de 0.0000
#   Voisin 49243 avec une distance de 0.0000
#   Voisin 49256 avec une distance de 0.0000
#   Voisin 49269 avec une distance de 0.0000
#   Voisin 49282 avec une distance de 0.0000
#   Voisin 49295 avec une distance de 0.0000
#   Voisin 49308 avec une distance de 0.0000
#   Voisin 49321 avec une distance de 0.0000
#   Voisin 49334 avec une distance de 0.0000
#   Voisin 49347 avec une distance de 0.0000
#   Voisin 49360 avec une distance de 0.0000
#   Voisin 49373 avec une distance de 0.0000
#   Voisin 49386 avec une distance de 0.0000
#   Voisin 49399 avec une distance de 0.0000
#   Voisin 49412 avec une distance de 0.0000
#   Voisin 49425 avec une distance de 0.0000
#   Voisin 49438 avec une distance de 0.0000
#   Voisin 49451 avec une distance de 0.0000
#   Voisin 49464 avec une distance de 0.0000
#   Voisin 49477 avec une distance de 0.0000
#   Voisin 49490 avec une distance de 0.0000
#   Voisin 49503 avec une distance de 0.0000
#   Voisin 49516 avec une distance de 0.0000
#   Voisin 49529 avec une distance de 0.0000
#   Voisin 49542 avec une distance de 0.0000
#   Voisin 49555 avec une distance de 0.0000
#   Voisin 49568 avec une distance de 0.0000
#   Voisin 49581 avec une distance de 0.0000
#   Voisin 49594 avec une distance de 0.0000
#   Voisin 49607 avec une distance de 0.0000
#   Voisin 49620 avec une distance de 0.0000
#   Voisin 49633 avec une distance de 0.0000
#   Voisin 49646 avec une distance de 0.0000
#   Voisin 49659 avec une distance de 0.0000
#   Voisin 49672 avec une distance de 0.0000
#   Voisin 49685 avec une distance de 0.0000
#   Voisin 49698 avec une distance de 0.0000
#   Voisin 49711 avec une distance de 0.0000
#   Voisin 49724 avec une distance de 0.0000
#   Voisin 49737 avec une distance de 0.0000
#   Voisin 49750 avec une distance de 0.0000
#   Voisin 49763 avec une distance de 0.0000
#   Voisin 49776 avec une distance de 0.0000
#   Voisin 49789 avec une distance de 0.0000
#   Voisin 49802 avec une distance de 0.0000
#   Voisin 49815 avec une distance de 0.0000
#   Voisin 49828 avec une distance de 0.0000
#   Voisin 49841 avec une distance de 0.0000
#   Voisin 49854 avec une distance de 0.0000
#   Voisin 49867 avec une distance de 0.0000
#   Voisin 49880 avec une distance de 0.0000
#   Voisin 49893 avec une distance de 0.0000
#   Voisin 49906 avec une distance de 0.0000
#   Voisin 49919 avec une distance de 0.0000
#   Voisin 49932 avec une distance de 0.0000
#   Voisin 49945 avec une distance de 0.0000
#   Voisin 49958 avec une distance de 0.0000
#   Voisin 49971 avec une distance de 0.0000
#   Voisin 49984 avec une distance de 0.0000
#   Voisin 49997 avec une distance de 0.0000
#   Voisin 50010 avec une distance de 0.0000
#   Voisin 50023 avec une distance de 0.0000
#   Voisin 50036 avec une distance de 0.0000
#   Voisin 50049 avec une distance de 0.0000
#   Voisin 50062 avec une distance de 0.0000
#   Voisin 50075 avec une distance de 0.0000
#   Voisin 50088 avec une distance de 0.0000
#   Voisin 50101 avec une distance de 0.0000
#   Voisin 50114 avec une distance de 0.0000
#   Voisin 50127 avec une distance de 0.0000
#   Voisin 50140 avec une distance de 0.0000
#   Voisin 50153 avec une distance de 0.0000
#   Voisin 50166 avec une distance de 0.0000
#   Voisin 50179 avec une distance de 0.0000
#   Voisin 50192 avec une distance de 0.0000
#   Voisin 50205 avec une distance de 0.0000
#   Voisin 50218 avec une distance de 0.0000
#   Voisin 50231 avec une distance de 0.0000
#   Voisin 50244 avec une distance de 0.0000
#   Voisin 50257 avec une distance de 0.0000
#   Voisin 50270 avec une distance de 0.0000
#   Voisin 50283 avec une distance de 0.0000
#   Voisin 50296 avec une distance de 0.0000
#   Voisin 50309 avec une distance de 0.0000
#   Voisin 50322 avec une distance de 0.0000
#   Voisin 50335 avec une distance de 0.0000
#   Voisin 50348 avec une distance de 0.0000
#   Voisin 50361 avec une distance de 0.0000
#   Voisin 50374 avec une distance de 0.0000
#   Voisin 50387 avec une distance de 0.0000
#   Voisin 50400 avec une distance de 0.0000
#   Voisin 50413 avec une distance de 0.0000
#   Voisin 50426 avec une distance de 0.0000
#   Voisin 50439 avec une distance de 0.0000
#   Voisin 50452 avec une distance de 0.0000
#   Voisin 50465 avec une distance de 0.0000
#   Voisin 50478 avec une distance de 0.0000
#   Voisin 50491 avec une distance de 0.0000
#   Voisin 50504 avec une distance de 0.0000
#   Voisin 50517 avec une distance de 0.0000
#   Voisin 50530 avec une distance de 0.0000
#   Voisin 50543 avec une distance de 0.0000
#   Voisin 50556 avec une distance de 0.0000
#   Voisin 50569 avec une distance de 0.0000
#   Voisin 50582 avec une distance de 0.0000
#   Voisin 50595 avec une distance de 0.0000
#   Voisin 50608 avec une distance de 0.0000
#   Voisin 50621 avec une distance de 0.0000
#   Voisin 50634 avec une distance de 0.0000
#   Voisin 50647 avec une distance de 0.0000
#   Voisin 50660 avec une distance de 0.0000
#   Voisin 50673 avec une distance de 0.0000
#   Voisin 50686 avec une distance de 0.0000
#   Voisin 50699 avec une distance de 0.0000
#   Voisin 50712 avec une distance de 0.0000
#   Voisin 50725 avec une distance de 0.0000
#   Voisin 50738 avec une distance de 0.0000
#   Voisin 50751 avec une distance de 0.0000
#   Voisin 50764 avec une distance de 0.0000
#   Voisin 50777 avec une distance de 0.0000
#   Voisin 50790 avec une distance de 0.0000
#   Voisin 50803 avec une distance de 0.0000
#   Voisin 50816 avec une distance de 0.0000
#   Voisin 50829 avec une distance de 0.0000
#   Voisin 50842 avec une distance de 0.0000
#   Voisin 50855 avec une distance de 0.0000
#   Voisin 50868 avec une distance de 0.0000
#   Voisin 50881 avec une distance de 0.0000
#   Voisin 50894 avec une distance de 0.0000
#   Voisin 50907 avec une distance de 0.0000
#   Voisin 50920 avec une distance de 0.0000
#   Voisin 50933 avec une distance de 0.0000
#   Voisin 50946 avec une distance de 0.0000
#   Voisin 50959 avec une distance de 0.0000
#   Voisin 50972 avec une distance de 0.0000
#   Voisin 50985 avec une distance de 0.0000
#   Voisin 50998 avec une distance de 0.0000
#   Voisin 51011 avec une distance de 0.0000
#   Voisin 51024 avec une distance de 0.0000
#   Voisin 51037 avec une distance de 0.0000
#   Voisin 51050 avec une distance de 0.0000
#   Voisin 51063 avec une distance de 0.0000
#   Voisin 51076 avec une distance de 0.0000
#   Voisin 51089 avec une distance de 0.0000
#   Voisin 51102 avec une distance de 0.0000
#   Voisin 51115 avec une distance de 0.0000
#   Voisin 51128 avec une distance de 0.0000
#   Voisin 51141 avec une distance de 0.0000
#   Voisin 51154 avec une distance de 0.0000
#   Voisin 51167 avec une distance de 0.0000
#   Voisin 51180 avec une distance de 0.0000
#   Voisin 51193 avec une distance de 0.0000
#   Voisin 51206 avec une distance de 0.0000
#   Voisin 51219 avec une distance de 0.0000
#   Voisin 51232 avec une distance de 0.0000
#   Voisin 51245 avec une distance de 0.0000
#   Voisin 51258 avec une distance de 0.0000
#   Voisin 51271 avec une distance de 0.0000
#   Voisin 51284 avec une distance de 0.0000
#   Voisin 51297 avec une distance de 0.0000
#   Voisin 51310 avec une distance de 0.0000
#   Voisin 51323 avec une distance de 0.0000
#   Voisin 51336 avec une distance de 0.0000
#   Voisin 51349 avec une distance de 0.0000
#   Voisin 51362 avec une distance de 0.0000
#   Voisin 51375 avec une distance de 0.0000
#   Voisin 51388 avec une distance de 0.0000
#   Voisin 51401 avec une distance de 0.0000
#   Voisin 51414 avec une distance de 0.0000
#   Voisin 51427 avec une distance de 0.0000
#   Voisin 51440 avec une distance de 0.0000
#   Voisin 51453 avec une distance de 0.0000
#   Voisin 51466 avec une distance de 0.0000
#   Voisin 51479 avec une distance de 0.0000
#   Voisin 51492 avec une distance de 0.0000
#   Voisin 51505 avec une distance de 0.0000
#   Voisin 51518 avec une distance de 0.0000
#   Voisin 51531 avec une distance de 0.0000
#   Voisin 51544 avec une distance de 0.0000
#   Voisin 51557 avec une distance de 0.0000
#   Voisin 51570 avec une distance de 0.0000
#   Voisin 51583 avec une distance de 0.0000
#   Voisin 51596 avec une distance de 0.0000
#   Voisin 51609 avec une distance de 0.0000
#   Voisin 51622 avec une distance de 0.0000
#   Voisin 51635 avec une distance de 0.0000
#   Voisin 51648 avec une distance de 0.0000
#   Voisin 51661 avec une distance de 0.0000
#   Voisin 51674 avec une distance de 0.0000
#   Voisin 51687 avec une distance de 0.0000
#   Voisin 51700 avec une distance de 0.0000
#   Voisin 51713 avec une distance de 0.0000
#   Voisin 51726 avec une distance de 0.0000
#   Voisin 51739 avec une distance de 0.0000
#   Voisin 51752 avec une distance de 0.0000
#   Voisin 51765 avec une distance de 0.0000
#   Voisin 51778 avec une distance de 0.0000
#   Voisin 51791 avec une distance de 0.0000
#   Voisin 51804 avec une distance de 0.0000
#   Voisin 51817 avec une distance de 0.0000
#   Voisin 51830 avec une distance de 0.0000
#   Voisin 51843 avec une distance de 0.0000
#   Voisin 51856 avec une distance de 0.0000
#   Voisin 51869 avec une distance de 0.0000
#   Voisin 51882 avec une distance de 0.0000
#   Voisin 51895 avec une distance de 0.0000
#   Voisin 51908 avec une distance de 0.0000
#   Voisin 51921 avec une distance de 0.0000
#   Voisin 51934 avec une distance de 0.0000
#   Voisin 51947 avec une distance de 0.0000
#   Voisin 51960 avec une distance de 0.0000
#   Voisin 51973 avec une distance de 0.0000
#   Voisin 51986 avec une distance de 0.0000
#   Voisin 51999 avec une distance de 0.0000
#   Voisin 52012 avec une distance de 0.0000
#   Voisin 52025 avec une distance de 0.0000
#   Voisin 52038 avec une distance de 0.0000
#   Voisin 52051 avec une distance de 0.0000
#   Voisin 52064 avec une distance de 0.0000
#   Voisin 52077 avec une distance de 0.0000
#   Voisin 52090 avec une distance de 0.0000
#   Voisin 52103 avec une distance de 0.0000
#   Voisin 52116 avec une distance de 0.0000
#   Voisin 52129 avec une distance de 0.0000
#   Voisin 52142 avec une distance de 0.0000
#   Voisin 52155 avec une distance de 0.0000
#   Voisin 52168 avec une distance de 0.0000
#   Voisin 52181 avec une distance de 0.0000
#   Voisin 52194 avec une distance de 0.0000
#   Voisin 52207 avec une distance de 0.0000
#   Voisin 52220 avec une distance de 0.0000
#   Voisin 52233 avec une distance de 0.0000
#   Voisin 52246 avec une distance de 0.0000
#   Voisin 52259 avec une distance de 0.0000
#   Voisin 52272 avec une distance de 0.0000
#   Voisin 52285 avec une distance de 0.0000
#   Voisin 52298 avec une distance de 0.0000
#   Voisin 52311 avec une distance de 0.0000
#   Voisin 52324 avec une distance de 0.0000
#   Voisin 52337 avec une distance de 0.0000
#   Voisin 52350 avec une distance de 0.0000
#   Voisin 52363 avec une distance de 0.0000
#   Voisin 52376 avec une distance de 0.0000
#   Voisin 52389 avec une distance de 0.0000
#   Voisin 52402 avec une distance de 0.0000
#   Voisin 52415 avec une distance de 0.0000
#   Voisin 52428 avec une distance de 0.0000
#   Voisin 52441 avec une distance de 0.0000
#   Voisin 52454 avec une distance de 0.0000
#   Voisin 52467 avec une distance de 0.0000
#   Voisin 52480 avec une distance de 0.0000
#   Voisin 52493 avec une distance de 0.0000
#   Voisin 52506 avec une distance de 0.0000
#   Voisin 52519 avec une distance de 0.0000
#   Voisin 52532 avec une distance de 0.0000
#   Voisin 52545 avec une distance de 0.0000
#   Voisin 52558 avec une distance de 0.0000
#   Voisin 52571 avec une distance de 0.0000
#   Voisin 52584 avec une distance de 0.0000
#   Voisin 52597 avec une distance de 0.0000
#   Voisin 52610 avec une distance de 0.0000
#   Voisin 52623 avec une distance de 0.0000
#   Voisin 52636 avec une distance de 0.0000
#   Voisin 52649 avec une distance de 0.0000
#   Voisin 52662 avec une distance de 0.0000
#   Voisin 52675 avec une distance de 0.0000
#   Voisin 52688 avec une distance de 0.0000
#   Voisin 52701 avec une distance de 0.0000
#   Voisin 52714 avec une distance de 0.0000
#   Voisin 52727 avec une distance de 0.0000
#   Voisin 52740 avec une distance de 0.0000
#   Voisin 52753 avec une distance de 0.0000
#   Voisin 52766 avec une distance de 0.0000
#   Voisin 52779 avec une distance de 0.0000
#   Voisin 52792 avec une distance de 0.0000
#   Voisin 52805 avec une distance de 0.0000
#   Voisin 52818 avec une distance de 0.0000
#   Voisin 52831 avec une distance de 0.0000
#   Voisin 52844 avec une distance de 0.0000
#   Voisin 52857 avec une distance de 0.0000
#   Voisin 52870 avec une distance de 0.0000
#   Voisin 52883 avec une distance de 0.0000
#   Voisin 52896 avec une distance de 0.0000
#   Voisin 52909 avec une distance de 0.0000
#   Voisin 52922 avec une distance de 0.0000
#   Voisin 52935 avec une distance de 0.0000
#   Voisin 52948 avec une distance de 0.0000
#   Voisin 52961 avec une distance de 0.0000
#   Voisin 52974 avec une distance de 0.0000
#   Voisin 52987 avec une distance de 0.0000
#   Voisin 53000 avec une distance de 0.0000
#   Voisin 53013 avec une distance de 0.0000
#   Voisin 53026 avec une distance de 0.0000
#   Voisin 53039 avec une distance de 0.0000
#   Voisin 53052 avec une distance de 0.0000
#   Voisin 53065 avec une distance de 0.0000
#   Voisin 53078 avec une distance de 0.0000
#   Voisin 53091 avec une distance de 0.0000
#   Voisin 53104 avec une distance de 0.0000
#   Voisin 53117 avec une distance de 0.0000
#   Voisin 53130 avec une distance de 0.0000
#   Voisin 53143 avec une distance de 0.0000
#   Voisin 53156 avec une distance de 0.0000
#   Voisin 53169 avec une distance de 0.0000
#   Voisin 53182 avec une distance de 0.0000
#   Voisin 53195 avec une distance de 0.0000
#   Voisin 53208 avec une distance de 0.0000
#   Voisin 53221 avec une distance de 0.0000
#   Voisin 53234 avec une distance de 0.0000
